# %%
import pyarrow.parquet as pq
import pyarrow as pa

# %%
df=pq.read_table(r"Y:\PROJECT\Renu\ILC_2024\Testing_EUWS\Results\ILC\BE\ILC2024_EUWS_PLA_WI_EP_BE_EUR_Losses\EP\Admin1_Lob\GU\ILC2024_EUWS_PLA_WI_EP_BE_EUR_EP_Admin1_Lob_GU_0.parquet").to_pandas()

# %%
df
# Out:
#       EPType          Loss  ReturnPeriod  Admin1Id      Admin1Name LOBName  \
# 0        OEP  4.252327e+07       10000.0  22525997  Brabant Wallon    AUTO
# 1        OEP  3.072026e+07        5000.0  22525997  Brabant Wallon    AUTO
# 2        OEP  1.591626e+07        1000.0  22525997  Brabant Wallon    AUTO
# 3        OEP  1.188185e+07         500.0  22525997  Brabant Wallon    AUTO
# 4        OEP  8.828825e+06         250.0  22525997  Brabant Wallon    AUTO
# ..       ...           ...           ...       ...             ...     ...
# 139  TCE-AEP  3.161450e+08          50.0  22525998  Vlaams Brabant    SPER
# 140  TCE-AEP  2.155147e+08          25.0  22525998  Vlaams Brabant    SPER
# 141  TCE-AEP  1.245959e+08          10.0  22525998  Vlaams Brabant    SPER
# 142  TCE-AEP  7.853886e+07           5.0  22525998  Vlaams Brabant    SPER
# 143  TCE-AEP  3.813824e+07           2.0  22525998  Vlaams Brabant    SPER
#
#     LOBId
# 0       2
# 1       2
# 2       2
# 3       2
# ...

# %%
df22=pq.read_table(r"D:\RISHIN\TESTING\TEST_3\ILC2024_EUWS_PLA_WI_EP_BE_EUR_Losses\processing\Resolution Added\PLT_0_100.parquet").to_pandas()

# %%
df22
# Out:
#           LocationId  LocationName LobName  LobId  PeriodId   EventId  \
# 0             883578   BE_AGR_7133     AGR      1         5  53863678
# 1             883529   BE_AGR_4140     AGR      1         8  53876196
# 2             883583   BE_AGR_7533     AGR      1         5  53863678
# 3             911623   BE_AGR_7534     AGR      1         5  53863678
# 4             943056   BE_AGR_7910     AGR      1         5  53863678
# ...              ...           ...     ...    ...       ...       ...
# 16580603      933343   BE_CAR_3832    AUTO      2      9497  53858319
# 16580604      903899   BE_COM_4653     COM      3      3321  53871525
# 16580605      914531  BE_RSFD_2630    SPER      5      9495  53856487
# 16580606      884027   BE_COM_4031     COM      3      3306  53884900
# 16580607      943494   BE_COM_4452     COM      3      3322  53874477
#
#             Weight  EventDate   LossDate Region Peril          Loss  \
# ...
